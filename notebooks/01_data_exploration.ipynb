# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import nbformat

# %%
df = pd.read_csv('/home/mouhcine/Desktop/NY-House-Prices-Project/data/raw/NY-House-Dataset.csv')

# %%
df

# %%
df.info()

# %%
df.head()

# %%
columns = df.columns
print(columns)
# Out:
# Index(['BROKERTITLE', 'TYPE', 'PRICE', 'BEDS', 'BATH', 'PROPERTYSQFT',
#        'ADDRESS', 'STATE', 'MAIN_ADDRESS', 'ADMINISTRATIVE_AREA_LEVEL_2',
#        'LOCALITY', 'SUBLOCALITY', 'STREET_NAME', 'LONG_NAME',
#        'FORMATTED_ADDRESS', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
plt.plot(df["PRICE"] , df["TYPE"])
plt.show()

# %%
columns_to_keep = ['TYPE' , 'PRICE' , 'PROPERTYSQFT' , 'STATE' , 'MAIN_ADDRESS' , 'ADMINISTRATIVE_AREA_LEVEL_2' , 'LOCALITY' , 'SUBLOCALITY']

# %%
columns_to_keep = [col for col in columns_to_keep if col in df.columns]

# %%
new_fd = df[columns_to_keep]

# %%
new_fd

# %%
new_fd.head()

# %%
max_price = new_fd['PRICE'].max()
print(max_price)

# %%
min_price = new_fd['PRICE'].min()
print(min_price)

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
stas_new_df = new_fd['PRICE'].describe()
print(stas_new_df)

# %%
plt.scatter(new_fd['PRICE'], new_fd['TYPE'])
plt.show()

# %%
plt.barh(new_fd['TYPE'], new_fd['PRICE'])
plt.show()

# %%
plt.hist(new_fd['PRICE'])
plt.show()

# %%
new_fd.isnull().melt(value_name='missing')

# %%
new_fd.isnull()

# %%
sns.displot(
    data=new_fd.isnull().melt(value_name='missing'),
    y='variable',
    hue='missing',
    multiple='fill',
    height=5,
    aspect=1.6
)
plt.axvline(0.4, color='r')
plt.title('Null Values in new_df Data', fontsize=13)
plt.show()

# %%
new_fd
# Out:
#                     TYPE      PRICE  PROPERTYSQFT                    STATE  \
# 0         Condo for sale     315000   1400.000000       New York, NY 10022
# 1         Condo for sale  195000000  17545.000000       New York, NY 10019
# 2         House for sale     260000   2015.000000  Staten Island, NY 10312
# 3         Condo for sale      69000    445.000000      Manhattan, NY 10022
# 4     Townhouse for sale   55000000  14175.000000       New York, NY 10065
# ...                  ...        ...           ...                      ...
# 4796      Co-op for sale     599000   2184.207862      Manhattan, NY 10075
# 4797      Co-op for sale     245000   2184.207862      Rego Park, NY 11374
# 4798      Co-op for sale    1275000   2184.207862       New York, NY 10011
# 4799      Condo for sale     598125    655.000000       Elmhurst, NY 11373
# 4800      Co-op for sale     349000    750.000000       Brooklyn, NY 11224
#
#                                            MAIN_ADDRESS  \
# ...

# %%
plt.scatter(new_fd['PRICE'], new_fd['PROPERTYSQFT'])
plt.show()

# %%
scatter_plot_multicolor_log = px.scatter(new_fd, x='PROPERTYSQFT', y='PRICE', color='TYPE',
                                          title='Price vs. Property Square Footage (Logarithmic Scale)',
                                          labels={'PROPERTYSQFT': 'Property Square Footage', 'PRICE': 'Price', 'TYPE': 'House Type'},
                                          log_x=True, log_y=True)

# %%
scatter_plot_multicolor_log.show()

# %%
missing_values_count = new_fd.isnull().sum()
missing_values_count
# Out:
# TYPE                           0
# PRICE                          0
# PROPERTYSQFT                   0
# STATE                          0
# MAIN_ADDRESS                   0
# ADMINISTRATIVE_AREA_LEVEL_2    0
# LOCALITY                       0
# SUBLOCALITY                    0
# dtype: int64

# %%
total_missing = missing_values_count.sum()
total_missing
# Out:
# np.int64(0)
