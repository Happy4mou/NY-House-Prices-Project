# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/mouhcine/Desktop/NY-House-Prices-Project/data/raw/NY-House-Dataset.csv')

# %%
df
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   float64
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
# ...

# %%
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
columns = df.columns
print(columns)
# Out:
# Index(['BROKERTITLE', 'TYPE', 'PRICE', 'BEDS', 'BATH', 'PROPERTYSQFT',
#        'ADDRESS', 'STATE', 'MAIN_ADDRESS', 'ADMINISTRATIVE_AREA_LEVEL_2',
#        'LOCALITY', 'SUBLOCALITY', 'STREET_NAME', 'LONG_NAME',
#        'FORMATTED_ADDRESS', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
plt.plot(df["TYPE"] , df["PRICE"])
plt.show()

# %%
columns_to_keep = ['TYPE' , 'PRICE' , 'PROPERTYSQFT' , 'STATE' , 'MAIN_ADDRESS' , 'ADMINISTRATIVE_AREA_LEVEL_2' , 'LOCALITY' , 'SUBLOCALITY']

# %%
columns_to_keep = [col for col in columns_to_keep if col in df.columns]

# %%
new_fd = df[columns_to_keep]

# %%
new_fd
# Out:
#                     TYPE      PRICE  PROPERTYSQFT                    STATE  \
# 0         Condo for sale     315000   1400.000000       New York, NY 10022
# 1         Condo for sale  195000000  17545.000000       New York, NY 10019
# 2         House for sale     260000   2015.000000  Staten Island, NY 10312
# 3         Condo for sale      69000    445.000000      Manhattan, NY 10022
# 4     Townhouse for sale   55000000  14175.000000       New York, NY 10065
# ...                  ...        ...           ...                      ...
# 4796      Co-op for sale     599000   2184.207862      Manhattan, NY 10075
# 4797      Co-op for sale     245000   2184.207862      Rego Park, NY 11374
# 4798      Co-op for sale    1275000   2184.207862       New York, NY 10011
# 4799      Condo for sale     598125    655.000000       Elmhurst, NY 11373
# 4800      Co-op for sale     349000    750.000000       Brooklyn, NY 11224
#
#                                            MAIN_ADDRESS  \
# ...

# %%
new_fd.head()
# Out:
#                  TYPE      PRICE  PROPERTYSQFT                    STATE  \
# 0      Condo for sale     315000        1400.0       New York, NY 10022
# 1      Condo for sale  195000000       17545.0       New York, NY 10019
# 2      House for sale     260000        2015.0  Staten Island, NY 10312
# 3      Condo for sale      69000         445.0      Manhattan, NY 10022
# 4  Townhouse for sale   55000000       14175.0       New York, NY 10065
#
#                                         MAIN_ADDRESS  \
# 0             2 E 55th St Unit 803New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...
# 2            620 Sinclair AveStaten Island, NY 10312
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022
# 4                      5 E 64th StNew York, NY 10065
#
#   ADMINISTRATIVE_AREA_LEVEL_2  LOCALITY      SUBLOCALITY
# 0             New York County  New York        Manhattan
# 1               United States  New York  New York County
# ...

# %%
max_price = new_fd['PRICE'].max()
print(max_price)
# Out:
# 2147483647

# %%
min_price = new_fd['PRICE'].min()
print(min_price)
# Out:
# 2494

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
stas_new_df = new_fd['PRICE'].describe()
print(stas_new_df)
# Out:
# count         4801.00
# mean       2356940.17
# std       31355246.26
# min           2494.00
# 25%         499000.00
# 50%         825000.00
# 75%        1495000.00
# max     2147483647.00
# Name: PRICE, dtype: float64
